# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ahmed Ramadan**
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I would love to contribute in clean energy_

# %% [markdown]
# ### The below should print 2+2 = 4

# %%
print('2+2 =',2+2)
# Out:
# 2+2 = 4

# %% [markdown]
# > You should be concetrate
# >
#  - Learn
#  - Teach
#
# <hr>
#
# Made by >>> [My Github](https://github.com/Ahmedelgaafary)
